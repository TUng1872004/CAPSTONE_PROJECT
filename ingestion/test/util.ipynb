# %%
import base64
def _encode_test_image() -> str:
    image_path = './asset/test.jpg'
    with open(image_path, "rb") as f:
        return base64.b64encode(f.read()).decode("utf-8")

# %%
_encode_test_image()
# Out:
# '...'

# %%
from pymilvus import (
    AsyncMilvusClient,
    DataType,
    FieldSchema,
    CollectionSchema,
)

# %%
uri = f"http://localhost:19530"
client = AsyncMilvusClient(
    uri=uri,
    user='',
    db_name='default',
    password='',
    timeout=30
)

# %%
await client.list_collections()
# Out:
# ['_123_image_embeddings',
#  '_123_text_caption_embeddings',
#  '_123_segment_caption_embeddings']
